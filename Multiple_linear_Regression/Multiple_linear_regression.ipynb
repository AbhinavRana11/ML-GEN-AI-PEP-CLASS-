# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing the dataset

# %%
filename ='machine.data'

df = pd.read_csv(filename, header = None)

# %% [markdown]
# ### Exploratry Data Analysis

# %%
print ("Shape of dataframe df: {}".format(df.shape))   #view the dimenssions of dataframe df
# Out:
# Shape of dataframe df: (209, 10)

# %% [markdown]
# ### Rename columns of dataframe df

# %%
df.columns = ['vendor', 'model', 'MYCT', 'MMIN', 'MMAX', 'CACH', 'CHMIN', 'CHMAX', 'PRP', 'ERP']
